# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.dont_write_bytecode = True

# %%
#imports
import os
import yaml
import json
import warnings
from itertools import product

import mlflow

import pandas as pd
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import f1_score, recall_score, roc_auc_score
import numpy as np
from datetime import datetime

from callables import parse_json
from callables import generate_features
from callables import process_features
from callables import model_train
from utils import plot_roc_curve, plot_confusion_matrix, plot_feature_importnaces, find_max_recall 

warnings.filterwarnings('ignore')

# %%
#params
with open("params.yml", 'r') as file:
    params = yaml.safe_load(file)

root_path = params['root_path']
filepath_input = root_path + params['filepath_input']
model_name = params['model_name']

feature_cols = params['feature_cols']

# shift_backwards = 1
# shift_forward = -1

anomaly_crtiretion = params['anomaly_crtiretion']

cb_params = params['cb_params']

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000')
mlflow.set_experiment("trading_model_b_shift_f_shift_recall_v2")
# Out:
# 2022/06/17 14:33:29 INFO mlflow.tracking.fluent: Experiment with name 'trading_model_b_shift_f_shift_recall_v2' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/3', experiment_id='3', lifecycle_stage='active', name='trading_model_b_shift_f_shift_recall_v2', tags={}>

# %%
shift_backwards_values = list(range(1,51))
shift_forward_values = list(range(1,51))

# %%
for shift_backwrd in shift_backwards_values:
        
    for shift_frwrd in shift_forward_values:
        
        #mlflow_start
        mlflow.start_run(run_name = f'b_{shift_backwrd}_f_{shift_frwrd}')
        
        #read
        df = parse_json(filepath_input)
        df = generate_features(
            df, feature_cols,
            shift_backwrd, shift_frwrd, 
            anomaly_crtiretion
        )
        df_event, df_period, df_model = process_features(df, feature_cols)

        #split
        train, test = train_test_split(df_model, test_size = 0.2, random_state = 42, shuffle = False)

        x_train = train.drop('target', axis = 1)
        y_train = train.target.astype(int)

        x_test = test.drop('target', axis = 1)
        y_test = test.target.astype(int)

        #fit best model
        model = CatBoostClassifier(**cb_params)
        model.fit(x_train, y_train)

        # predict train probabilities
        y_train_pred_proba = model.predict_proba(x_train)
        y_train_pred_proba = y_train_pred_proba[:, 1]

        # predict test probabilities
        y_test_pred_proba = model.predict_proba(x_test)
        y_test_pred_proba = y_test_pred_proba[:, 1]

        #opt_cutoff
        opt_cutoff = find_max_recall(y_test, y_test_pred_proba)

        #calculate metrics
        recall_score_train = recall_score(y_train, (y_train_pred_proba > opt_cutoff), pos_label=1, average='binary')
        recall_score_test  = recall_score(y_test , (y_test_pred_proba  > opt_cutoff), pos_label=1, average='binary')

        #________________________________________________________________________

        # mlflow log params

        mlflow.log_param("shift_bckwrd", shift_backwrd)
        mlflow.log_param("shift_frwrd", shift_frwrd)
        mlflow.log_param("anomaly_crtiretion", anomaly_crtiretion)

        # mlflow log metrics
        mlflow.log_metric("recall_score_train", recall_score_train)
        mlflow.log_metric("recall_score_test", recall_score_test)

       #________________________________________________________________________
    
        #mlflow_end
        mlflow.end_run()
        
        print(f'success_run_b_{shift_backwrd}_f_{shift_frwrd}')
# Out:
# success_run_b_1_f_1
# success_run_b_1_f_2
# success_run_b_1_f_3
# success_run_b_1_f_4
# success_run_b_1_f_5
# success_run_b_1_f_6
# success_run_b_1_f_7
# success_run_b_1_f_8
# success_run_b_1_f_9
# success_run_b_1_f_10
# success_run_b_1_f_11
# success_run_b_1_f_12
# success_run_b_1_f_13
# success_run_b_1_f_14
# success_run_b_1_f_15
# success_run_b_1_f_16
# success_run_b_1_f_17
# success_run_b_1_f_18
# success_run_b_1_f_19
# success_run_b_1_f_20
# success_run_b_1_f_21
# success_run_b_1_f_22
# success_run_b_1_f_23
# success_run_b_1_f_24
# success_run_b_1_f_25
# success_run_b_1_f_26
# success_run_b_1_f_27
# success_run_b_1_f_28
# success_run_b_1_f_29
# success_run_b_1_f_30
# success_run_b_1_f_31
# success_run_b_1_f_32
# success_run_b_1_f_33
# success_run_b_1_f_34
# success_run_b_1_f_35
# success_run_b_1_f_36
# success_run_b_1_f_37
# success_run_b_1_f_38
# success_run_b_1_f_39
# success_run_b_1_f_40
# success_run_b_1_f_41
# success_run_b_1_f_42
# success_run_b_1_f_43
# success_run_b_1_f_44
# success_run_b_1_f_45
# success_run_b_1_f_46
# success_run_b_1_f_47
# success_run_b_1_f_48
# success_run_b_1_f_49
# success_run_b_1_f_50
# success_run_b_2_f_1
# success_run_b_2_f_2
# success_run_b_2_f_3
# success_run_b_2_f_4
# success_run_b_2_f_5
# success_run_b_2_f_6
# success_run_b_2_f_7
# success_run_b_2_f_8
# success_run_b_2_f_9
# success_run_b_2_f_10
# success_run_b_2_f_11
# success_run_b_2_f_12
# success_run_b_2_f_13
# success_run_b_2_f_14
# success_run_b_2_f_15
# success_run_b_2_f_16
# success_run_b_2_f_17
# success_run_b_2_f_18
# success_run_b_2_f_19
# success_run_b_2_f_20
# success_run_b_2_f_21
# success_run_b_2_f_22
# success_run_b_2_f_23
# success_run_b_2_f_24
# success_run_b_2_f_25
# success_run_b_2_f_26
# success_run_b_2_f_27
# success_run_b_2_f_28
# success_run_b_2_f_29
# success_run_b_2_f_30
# success_run_b_2_f_31
# success_run_b_2_f_32
# success_run_b_2_f_33
# success_run_b_2_f_34
# success_run_b_2_f_35
# success_run_b_2_f_36
# success_run_b_2_f_37
# success_run_b_2_f_38
# success_run_b_2_f_39
# success_run_b_2_f_40
# success_run_b_2_f_41
# success_run_b_2_f_42
# success_run_b_2_f_43
# success_run_b_2_f_44
# success_run_b_2_f_45
# success_run_b_2_f_46
# success_run_b_2_f_47
# success_run_b_2_f_48
# success_run_b_2_f_49
# success_run_b_2_f_50
# success_run_b_3_f_1
# success_run_b_3_f_2
# success_run_b_3_f_3
# success_run_b_3_f_4
# success_run_b_3_f_5
# success_run_b_3_f_6
# success_run_b_3_f_7
# success_run_b_3_f_8
# success_run_b_3_f_9
# success_run_b_3_f_10
# success_run_b_3_f_11
# success_run_b_3_f_12
# success_run_b_3_f_13
# success_run_b_3_f_14
# success_run_b_3_f_15
# success_run_b_3_f_16
# success_run_b_3_f_17
# success_run_b_3_f_18
# success_run_b_3_f_19
# success_run_b_3_f_20
# success_run_b_3_f_21
# success_run_b_3_f_22
# success_run_b_3_f_23
# success_run_b_3_f_24
# success_run_b_3_f_25
# success_run_b_3_f_26
# success_run_b_3_f_27
# success_run_b_3_f_28
# success_run_b_3_f_29
# success_run_b_3_f_30
# success_run_b_3_f_31
# success_run_b_3_f_32
# success_run_b_3_f_33
# success_run_b_3_f_34
# success_run_b_3_f_35
# success_run_b_3_f_36
# success_run_b_3_f_37
# success_run_b_3_f_38
# success_run_b_3_f_39
# success_run_b_3_f_40
# success_run_b_3_f_41
# success_run_b_3_f_42
# success_run_b_3_f_43
# success_run_b_3_f_44
# success_run_b_3_f_45
# success_run_b_3_f_46
# success_run_b_3_f_47
# success_run_b_3_f_48
# success_run_b_3_f_49
# success_run_b_3_f_50
# success_run_b_4_f_1
# success_run_b_4_f_2
# success_run_b_4_f_3
# success_run_b_4_f_4
# success_run_b_4_f_5
# success_run_b_4_f_6
# success_run_b_4_f_7
# success_run_b_4_f_8
# success_run_b_4_f_9
# success_run_b_4_f_10
# success_run_b_4_f_11
# success_run_b_4_f_12
# success_run_b_4_f_13
# success_run_b_4_f_14
# success_run_b_4_f_15
# success_run_b_4_f_16
# success_run_b_4_f_17
# success_run_b_4_f_18
# success_run_b_4_f_19
# success_run_b_4_f_20
# success_run_b_4_f_21
# success_run_b_4_f_22
# success_run_b_4_f_23
# success_run_b_4_f_24
# success_run_b_4_f_25
# success_run_b_4_f_26
# success_run_b_4_f_27
# success_run_b_4_f_28
# success_run_b_4_f_29
# success_run_b_4_f_30
# success_run_b_4_f_31
# success_run_b_4_f_32
# success_run_b_4_f_33
# success_run_b_4_f_34
# success_run_b_4_f_35
# success_run_b_4_f_36
# success_run_b_4_f_37
# success_run_b_4_f_38
# success_run_b_4_f_39
# success_run_b_4_f_40
# success_run_b_4_f_41
# success_run_b_4_f_42
# success_run_b_4_f_43
# success_run_b_4_f_44
# success_run_b_4_f_45
# success_run_b_4_f_46
# success_run_b_4_f_47
# success_run_b_4_f_48
# success_run_b_4_f_49
# success_run_b_4_f_50
# success_run_b_5_f_1
# success_run_b_5_f_2
# success_run_b_5_f_3
# success_run_b_5_f_4
# success_run_b_5_f_5
# success_run_b_5_f_6
# success_run_b_5_f_7
# success_run_b_5_f_8
# success_run_b_5_f_9
# success_run_b_5_f_10
# success_run_b_5_f_11
# success_run_b_5_f_12
# success_run_b_5_f_13
# success_run_b_5_f_14
# success_run_b_5_f_15
# success_run_b_5_f_16
# success_run_b_5_f_17
# success_run_b_5_f_18
# success_run_b_5_f_19
# success_run_b_5_f_20
# success_run_b_5_f_21
# success_run_b_5_f_22
# success_run_b_5_f_23
# success_run_b_5_f_24
# success_run_b_5_f_25
# success_run_b_5_f_26
# success_run_b_5_f_27
# success_run_b_5_f_28
# success_run_b_5_f_29
# success_run_b_5_f_30
# success_run_b_5_f_31
# success_run_b_5_f_32
# success_run_b_5_f_33
# success_run_b_5_f_34
# success_run_b_5_f_35
# success_run_b_5_f_36
# success_run_b_5_f_37
# success_run_b_5_f_38
# success_run_b_5_f_39
# success_run_b_5_f_40
# success_run_b_5_f_41
# success_run_b_5_f_42
# success_run_b_5_f_43
# success_run_b_5_f_44
# success_run_b_5_f_45
# success_run_b_5_f_46
# success_run_b_5_f_47
# success_run_b_5_f_48
# success_run_b_5_f_49
# success_run_b_5_f_50
# success_run_b_6_f_1
# success_run_b_6_f_2
# success_run_b_6_f_3
# success_run_b_6_f_4
# success_run_b_6_f_5
# success_run_b_6_f_6
# success_run_b_6_f_7
# success_run_b_6_f_8
# success_run_b_6_f_9
# success_run_b_6_f_10
# success_run_b_6_f_11
# success_run_b_6_f_12
# success_run_b_6_f_13
# success_run_b_6_f_14
# success_run_b_6_f_15
# success_run_b_6_f_16
# success_run_b_6_f_17
# success_run_b_6_f_18
# success_run_b_6_f_19
# success_run_b_6_f_20
# success_run_b_6_f_21
# success_run_b_6_f_22
# success_run_b_6_f_23
# success_run_b_6_f_24
# success_run_b_6_f_25
# success_run_b_6_f_26
# success_run_b_6_f_27
# success_run_b_6_f_28
# success_run_b_6_f_29
# success_run_b_6_f_30
# success_run_b_6_f_31
# success_run_b_6_f_32
# success_run_b_6_f_33
# success_run_b_6_f_34
# success_run_b_6_f_35
# success_run_b_6_f_36
# success_run_b_6_f_37
# success_run_b_6_f_38
# success_run_b_6_f_39
# success_run_b_6_f_40
# success_run_b_6_f_41
# success_run_b_6_f_42
# success_run_b_6_f_43
# success_run_b_6_f_44
# success_run_b_6_f_45
# success_run_b_6_f_46
# success_run_b_6_f_47
# success_run_b_6_f_48
# success_run_b_6_f_49
# success_run_b_6_f_50
# success_run_b_7_f_1
# success_run_b_7_f_2
# success_run_b_7_f_3
# success_run_b_7_f_4
# success_run_b_7_f_5
# success_run_b_7_f_6
# success_run_b_7_f_7
# success_run_b_7_f_8
# success_run_b_7_f_9
# success_run_b_7_f_10
# success_run_b_7_f_11
# success_run_b_7_f_12
# success_run_b_7_f_13
# success_run_b_7_f_14
# success_run_b_7_f_15
# success_run_b_7_f_16
# success_run_b_7_f_17
# success_run_b_7_f_18
# success_run_b_7_f_19
# success_run_b_7_f_20
# success_run_b_7_f_21
# success_run_b_7_f_22
# success_run_b_7_f_23
# success_run_b_7_f_24
# success_run_b_7_f_25
# success_run_b_7_f_26
# success_run_b_7_f_27
# success_run_b_7_f_28
# success_run_b_7_f_29
# success_run_b_7_f_30
# success_run_b_7_f_31
# success_run_b_7_f_32
# success_run_b_7_f_33
# success_run_b_7_f_34
# success_run_b_7_f_35
# success_run_b_7_f_36
# success_run_b_7_f_37
# success_run_b_7_f_38
# success_run_b_7_f_39
# success_run_b_7_f_40
# success_run_b_7_f_41
# success_run_b_7_f_42
# success_run_b_7_f_43
# success_run_b_7_f_44
# success_run_b_7_f_45
# success_run_b_7_f_46
# success_run_b_7_f_47
# success_run_b_7_f_48
# success_run_b_7_f_49
# success_run_b_7_f_50
# success_run_b_8_f_1
# success_run_b_8_f_2
# success_run_b_8_f_3
# success_run_b_8_f_4
# success_run_b_8_f_5
# success_run_b_8_f_6
# success_run_b_8_f_7
# success_run_b_8_f_8
# success_run_b_8_f_9
# success_run_b_8_f_10
# success_run_b_8_f_11
# success_run_b_8_f_12
# success_run_b_8_f_13
# success_run_b_8_f_14
# success_run_b_8_f_15
# success_run_b_8_f_16
# success_run_b_8_f_17
# success_run_b_8_f_18
# success_run_b_8_f_19
# success_run_b_8_f_20
# success_run_b_8_f_21
# success_run_b_8_f_22
# success_run_b_8_f_23
# success_run_b_8_f_24
# success_run_b_8_f_25
# success_run_b_8_f_26
# success_run_b_8_f_27
# success_run_b_8_f_28
# success_run_b_8_f_29
# success_run_b_8_f_30
# success_run_b_8_f_31
# success_run_b_8_f_32
# success_run_b_8_f_33
# success_run_b_8_f_34
# success_run_b_8_f_35
# success_run_b_8_f_36
# success_run_b_8_f_37
# success_run_b_8_f_38
# success_run_b_8_f_39
# success_run_b_8_f_40
# success_run_b_8_f_41
# success_run_b_8_f_42
# success_run_b_8_f_43
# success_run_b_8_f_44
# success_run_b_8_f_45
# success_run_b_8_f_46
# success_run_b_8_f_47
# success_run_b_8_f_48
# success_run_b_8_f_49
# success_run_b_8_f_50
# success_run_b_9_f_1
# success_run_b_9_f_2
# success_run_b_9_f_3
# success_run_b_9_f_4
# success_run_b_9_f_5
# success_run_b_9_f_6
# success_run_b_9_f_7
# success_run_b_9_f_8
# success_run_b_9_f_9
# success_run_b_9_f_10
# success_run_b_9_f_11
# success_run_b_9_f_12
# success_run_b_9_f_13
# success_run_b_9_f_14
# success_run_b_9_f_15
# success_run_b_9_f_16
# success_run_b_9_f_17
# success_run_b_9_f_18
# success_run_b_9_f_19
# success_run_b_9_f_20
# success_run_b_9_f_21
# success_run_b_9_f_22
# success_run_b_9_f_23
# success_run_b_9_f_24
# success_run_b_9_f_25
# success_run_b_9_f_26
# success_run_b_9_f_27
# success_run_b_9_f_28
# success_run_b_9_f_29
# success_run_b_9_f_30
# success_run_b_9_f_31
# success_run_b_9_f_32
# success_run_b_9_f_33
# success_run_b_9_f_34
# success_run_b_9_f_35
# success_run_b_9_f_36
# success_run_b_9_f_37
# success_run_b_9_f_38
# success_run_b_9_f_39
# success_run_b_9_f_40
# success_run_b_9_f_41
# success_run_b_9_f_42
# success_run_b_9_f_43
# success_run_b_9_f_44
# success_run_b_9_f_45
# success_run_b_9_f_46
# success_run_b_9_f_47
# success_run_b_9_f_48
# success_run_b_9_f_49
# success_run_b_9_f_50
# success_run_b_10_f_1
# success_run_b_10_f_2
# success_run_b_10_f_3
# success_run_b_10_f_4
# success_run_b_10_f_5
# success_run_b_10_f_6
# success_run_b_10_f_7
# success_run_b_10_f_8
# success_run_b_10_f_9
# success_run_b_10_f_10
# success_run_b_10_f_11
# success_run_b_10_f_12
# success_run_b_10_f_13
# success_run_b_10_f_14
# success_run_b_10_f_15
# success_run_b_10_f_16
# success_run_b_10_f_17
# success_run_b_10_f_18
# success_run_b_10_f_19
# success_run_b_10_f_20
# success_run_b_10_f_21
# success_run_b_10_f_22
# success_run_b_10_f_23
# success_run_b_10_f_24
# success_run_b_10_f_25
# success_run_b_10_f_26
# success_run_b_10_f_27
# success_run_b_10_f_28
# success_run_b_10_f_29
# success_run_b_10_f_30
# success_run_b_10_f_31
# success_run_b_10_f_32
# success_run_b_10_f_33
# success_run_b_10_f_34
# success_run_b_10_f_35
# success_run_b_10_f_36
# success_run_b_10_f_37
# success_run_b_10_f_38
# success_run_b_10_f_39
# success_run_b_10_f_40
# success_run_b_10_f_41
# success_run_b_10_f_42
# success_run_b_10_f_43
# success_run_b_10_f_44
# success_run_b_10_f_45
# success_run_b_10_f_46
# success_run_b_10_f_47
# success_run_b_10_f_48
# success_run_b_10_f_49
# success_run_b_10_f_50
# success_run_b_11_f_1
# success_run_b_11_f_2
# success_run_b_11_f_3
# success_run_b_11_f_4
# success_run_b_11_f_5
# success_run_b_11_f_6
# success_run_b_11_f_7
# success_run_b_11_f_8
# success_run_b_11_f_9
# success_run_b_11_f_10
# success_run_b_11_f_11
# success_run_b_11_f_12
# success_run_b_11_f_13
# success_run_b_11_f_14
# success_run_b_11_f_15
# success_run_b_11_f_16
# success_run_b_11_f_17
# success_run_b_11_f_18
# success_run_b_11_f_19
# success_run_b_11_f_20
# success_run_b_11_f_21
# success_run_b_11_f_22
# success_run_b_11_f_23
# success_run_b_11_f_24
# success_run_b_11_f_25
# success_run_b_11_f_26
# success_run_b_11_f_27
# success_run_b_11_f_28
# success_run_b_11_f_29
# success_run_b_11_f_30
# success_run_b_11_f_31
# success_run_b_11_f_32
# success_run_b_11_f_33
# success_run_b_11_f_34
# success_run_b_11_f_35
# success_run_b_11_f_36
# success_run_b_11_f_37
# success_run_b_11_f_38
# success_run_b_11_f_39
# success_run_b_11_f_40
# success_run_b_11_f_41
# success_run_b_11_f_42
# success_run_b_11_f_43
# success_run_b_11_f_44
# success_run_b_11_f_45
# success_run_b_11_f_46
# success_run_b_11_f_47
# success_run_b_11_f_48
# success_run_b_11_f_49
# success_run_b_11_f_50
# success_run_b_12_f_1
# success_run_b_12_f_2
# success_run_b_12_f_3
# success_run_b_12_f_4
# success_run_b_12_f_5
# success_run_b_12_f_6
# success_run_b_12_f_7
# success_run_b_12_f_8
# success_run_b_12_f_9
# success_run_b_12_f_10
# success_run_b_12_f_11
# success_run_b_12_f_12
# success_run_b_12_f_13
# success_run_b_12_f_14
# success_run_b_12_f_15
# success_run_b_12_f_16
# success_run_b_12_f_17
# success_run_b_12_f_18
# success_run_b_12_f_19
# success_run_b_12_f_20
# success_run_b_12_f_21
# success_run_b_12_f_22
# success_run_b_12_f_23
# success_run_b_12_f_24
# success_run_b_12_f_25
# success_run_b_12_f_26
# success_run_b_12_f_27
# success_run_b_12_f_28
# success_run_b_12_f_29
# success_run_b_12_f_30
# success_run_b_12_f_31
# success_run_b_12_f_32
# success_run_b_12_f_33
# success_run_b_12_f_34
# success_run_b_12_f_35
# success_run_b_12_f_36
# success_run_b_12_f_37
# success_run_b_12_f_38
# success_run_b_12_f_39
# success_run_b_12_f_40
# success_run_b_12_f_41
# success_run_b_12_f_42
# success_run_b_12_f_43
# success_run_b_12_f_44
# success_run_b_12_f_45
# success_run_b_12_f_46
# success_run_b_12_f_47
# success_run_b_12_f_48
# success_run_b_12_f_49
# success_run_b_12_f_50
# success_run_b_13_f_1
# success_run_b_13_f_2
# success_run_b_13_f_3
# success_run_b_13_f_4
# success_run_b_13_f_5
# success_run_b_13_f_6
# success_run_b_13_f_7
# success_run_b_13_f_8
# success_run_b_13_f_9
# success_run_b_13_f_10
# success_run_b_13_f_11
# success_run_b_13_f_12
# success_run_b_13_f_13
# success_run_b_13_f_14
# success_run_b_13_f_15
# success_run_b_13_f_16
# success_run_b_13_f_17
# success_run_b_13_f_18
# success_run_b_13_f_19
# success_run_b_13_f_20
# success_run_b_13_f_21
# success_run_b_13_f_22
# success_run_b_13_f_23
# success_run_b_13_f_24
# success_run_b_13_f_25
# success_run_b_13_f_26
# success_run_b_13_f_27
# success_run_b_13_f_28
# success_run_b_13_f_29
# success_run_b_13_f_30
# success_run_b_13_f_31
# success_run_b_13_f_32
# success_run_b_13_f_33
# success_run_b_13_f_34
# success_run_b_13_f_35
# success_run_b_13_f_36
# success_run_b_13_f_37
# success_run_b_13_f_38
# success_run_b_13_f_39
# success_run_b_13_f_40
# success_run_b_13_f_41
# success_run_b_13_f_42
# success_run_b_13_f_43
# success_run_b_13_f_44
# success_run_b_13_f_45
# success_run_b_13_f_46
# success_run_b_13_f_47
# success_run_b_13_f_48
# success_run_b_13_f_49
# success_run_b_13_f_50
# success_run_b_14_f_1
# success_run_b_14_f_2
# success_run_b_14_f_3
# success_run_b_14_f_4
# success_run_b_14_f_5
# success_run_b_14_f_6
# success_run_b_14_f_7
# success_run_b_14_f_8
# success_run_b_14_f_9
# success_run_b_14_f_10
# success_run_b_14_f_11
# success_run_b_14_f_12
# success_run_b_14_f_13
# success_run_b_14_f_14
# success_run_b_14_f_15
# success_run_b_14_f_16
# success_run_b_14_f_17
# success_run_b_14_f_18
# success_run_b_14_f_19
# success_run_b_14_f_20
# success_run_b_14_f_21
# success_run_b_14_f_22
# success_run_b_14_f_23
# success_run_b_14_f_24
# success_run_b_14_f_25
# success_run_b_14_f_26
# success_run_b_14_f_27
# success_run_b_14_f_28
# success_run_b_14_f_29
# success_run_b_14_f_30
# success_run_b_14_f_31
# success_run_b_14_f_32
# success_run_b_14_f_33
# success_run_b_14_f_34
# success_run_b_14_f_35
# success_run_b_14_f_36
# success_run_b_14_f_37
# success_run_b_14_f_38
# success_run_b_14_f_39
# success_run_b_14_f_40
# success_run_b_14_f_41
# success_run_b_14_f_42
# success_run_b_14_f_43
# success_run_b_14_f_44
# success_run_b_14_f_45
# success_run_b_14_f_46
# success_run_b_14_f_47
# success_run_b_14_f_48
# success_run_b_14_f_49
# success_run_b_14_f_50
# success_run_b_15_f_1
# success_run_b_15_f_2
# success_run_b_15_f_3
# success_run_b_15_f_4
# success_run_b_15_f_5
# success_run_b_15_f_6
# success_run_b_15_f_7
# success_run_b_15_f_8
# success_run_b_15_f_9
# success_run_b_15_f_10
# success_run_b_15_f_11
# success_run_b_15_f_12
# success_run_b_15_f_13
# success_run_b_15_f_14
# success_run_b_15_f_15
# success_run_b_15_f_16
# success_run_b_15_f_17
# success_run_b_15_f_18
# success_run_b_15_f_19
# success_run_b_15_f_20
# success_run_b_15_f_21
# success_run_b_15_f_22
# success_run_b_15_f_23
# success_run_b_15_f_24
# success_run_b_15_f_25
# success_run_b_15_f_26
# success_run_b_15_f_27
# success_run_b_15_f_28
# success_run_b_15_f_29
# success_run_b_15_f_30
# success_run_b_15_f_31
# success_run_b_15_f_32
# success_run_b_15_f_33
# success_run_b_15_f_34
# success_run_b_15_f_35
# success_run_b_15_f_36
# success_run_b_15_f_37
# success_run_b_15_f_38
# success_run_b_15_f_39
# success_run_b_15_f_40
# success_run_b_15_f_41
# success_run_b_15_f_42
# success_run_b_15_f_43
# success_run_b_15_f_44
# success_run_b_15_f_45
# success_run_b_15_f_46
# success_run_b_15_f_47
# success_run_b_15_f_48
# success_run_b_15_f_49
# success_run_b_15_f_50
# success_run_b_16_f_1
# success_run_b_16_f_2
# success_run_b_16_f_3
# success_run_b_16_f_4
# success_run_b_16_f_5
# success_run_b_16_f_6
# success_run_b_16_f_7
# success_run_b_16_f_8
# success_run_b_16_f_9
# success_run_b_16_f_10
# success_run_b_16_f_11
# success_run_b_16_f_12
# success_run_b_16_f_13
# success_run_b_16_f_14
# success_run_b_16_f_15
# success_run_b_16_f_16
# success_run_b_16_f_17
# success_run_b_16_f_18
# success_run_b_16_f_19
# success_run_b_16_f_20
# success_run_b_16_f_21
# success_run_b_16_f_22
# success_run_b_16_f_23
# success_run_b_16_f_24
# success_run_b_16_f_25
# success_run_b_16_f_26
# success_run_b_16_f_27
# success_run_b_16_f_28
# success_run_b_16_f_29
# success_run_b_16_f_30
# success_run_b_16_f_31
# success_run_b_16_f_32
# success_run_b_16_f_33
# success_run_b_16_f_34
# success_run_b_16_f_35
# success_run_b_16_f_36
# success_run_b_16_f_37
# success_run_b_16_f_38
# success_run_b_16_f_39
# success_run_b_16_f_40
# success_run_b_16_f_41
# success_run_b_16_f_42
# success_run_b_16_f_43
# success_run_b_16_f_44
# success_run_b_16_f_45
# success_run_b_16_f_46
# success_run_b_16_f_47
# success_run_b_16_f_48
# success_run_b_16_f_49
# success_run_b_16_f_50
# success_run_b_17_f_1
# success_run_b_17_f_2
# success_run_b_17_f_3
# success_run_b_17_f_4
# success_run_b_17_f_5
# success_run_b_17_f_6
# success_run_b_17_f_7
# success_run_b_17_f_8
# success_run_b_17_f_9
# success_run_b_17_f_10
# success_run_b_17_f_11
# success_run_b_17_f_12
# success_run_b_17_f_13
# success_run_b_17_f_14
# success_run_b_17_f_15
# success_run_b_17_f_16
# success_run_b_17_f_17
# success_run_b_17_f_18
# success_run_b_17_f_19
# success_run_b_17_f_20
# success_run_b_17_f_21
# success_run_b_17_f_22
# success_run_b_17_f_23
# success_run_b_17_f_24
# success_run_b_17_f_25
# success_run_b_17_f_26
# success_run_b_17_f_27
# success_run_b_17_f_28
# success_run_b_17_f_29
# success_run_b_17_f_30
# success_run_b_17_f_31
# success_run_b_17_f_32
# success_run_b_17_f_33
# success_run_b_17_f_34
# success_run_b_17_f_35
# success_run_b_17_f_36
# success_run_b_17_f_37
# success_run_b_17_f_38
# success_run_b_17_f_39
# success_run_b_17_f_40
# success_run_b_17_f_41
# success_run_b_17_f_42
# success_run_b_17_f_43
# success_run_b_17_f_44
# success_run_b_17_f_45
# success_run_b_17_f_46
# success_run_b_17_f_47
# success_run_b_17_f_48
# success_run_b_17_f_49
